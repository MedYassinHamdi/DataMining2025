# %%
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
import warnings
warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv(r'C:\Users\ASUS\Downloads\produits.csv')
dataset
# Out:
#    B  P  S  C  E
# 0  1  0  1  1  1
# 1  0  1  0  1  0
# 2  0  0  1  1  1
# 3  1  0  0  0  1
# 4  0  1  1  1  0

# %%
dataset = dataset.astype('bool')
dataset
# Out:
#        B      P      S      C      E
# 0   True  False   True   True   True
# 1  False   True  False   True  False
# 2  False  False   True   True   True
# 3   True  False  False  False   True
# 4  False   True   True   True  False

# %%
frequent_itemsets = apriori(dataset, min_support=0.4, use_colnames=True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(len)
frequent_itemsets
# Out:
#     support   itemsets  length
# 0       0.4        (B)       1
# 1       0.4        (P)       1
# 2       0.6        (S)       1
# 3       0.8        (C)       1
# 4       0.6        (E)       1
# 5       0.4     (B, E)       2
# 6       0.4     (C, P)       2
# 7       0.6     (C, S)       2
# 8       0.4     (E, S)       2
# 9       0.4     (C, E)       2
# 10      0.4  (C, E, S)       3

# %%
frequent_itemsets[frequent_itemsets['length'] == 2]
# Out:
#    support itemsets  length
# 5      0.4   (B, E)       2
# 6      0.4   (C, P)       2
# 7      0.6   (C, S)       2
# 8      0.4   (E, S)       2
# 9      0.4   (C, E)       2

# %%
frequent_itemsets[frequent_itemsets['length'] >= 3]
# Out:
#     support   itemsets  length
# 10      0.4  (C, E, S)       3

# %%
frequent_itemsets[(frequent_itemsets['length'] >= 2) & (frequent_itemsets['itemsets'].ge({'C'}))]
# Out:
#     support   itemsets  length
# 6       0.4     (C, P)       2
# 7       0.6     (C, S)       2
# 9       0.4     (C, E)       2
# 10      0.4  (C, E, S)       3

# %%
rules1 = association_rules(frequent_itemsets,metric="confidence", min_threshold=0.6)
rules1
# Out:
#    antecedents consequents  antecedent support  consequent support  support  \
# 0          (B)         (E)                 0.4                 0.6      0.4
# 1          (E)         (B)                 0.6                 0.4      0.4
# 2          (P)         (C)                 0.4                 0.8      0.4
# 3          (C)         (S)                 0.8                 0.6      0.6
# 4          (S)         (C)                 0.6                 0.8      0.6
# 5          (E)         (S)                 0.6                 0.6      0.4
# 6          (S)         (E)                 0.6                 0.6      0.4
# 7          (E)         (C)                 0.6                 0.8      0.4
# 8       (C, E)         (S)                 0.4                 0.6      0.4
# 9       (C, S)         (E)                 0.6                 0.6      0.4
# 10      (E, S)         (C)                 0.4                 0.8      0.4
# 11         (E)      (C, S)                 0.6                 0.6      0.4
# 12         (S)      (C, E)                 0.6                 0.4      0.4
#
#     confidence      lift  representativity  leverage  conviction  \
# 0     1.000000  1.666667               1.0      0.16         inf
# 1     0.666667  1.666667               1.0      0.16         1.8
# 2     1.000000  1.250000               1.0      0.08         inf
# 3     0.750000  1.250000               1.0      0.12         1.6
# 4     1.000000  1.250000               1.0      0.12         inf
# 5     0.666667  1.111111               1.0      0.04         1.2
# 6     0.666667  1.111111               1.0      0.04         1.2
# 7     0.666667  0.833333               1.0     -0.08         0.6
# 8     1.000000  1.666667               1.0      0.16         inf
# 9     0.666667  1.111111               1.0      0.04         1.2
# 10    1.000000  1.250000               1.0      0.08         inf
# 11    0.666667  1.111111               1.0      0.04         1.2
# 12    0.666667  1.666667               1.0      0.16         1.8
#
#     zhangs_metric   jaccard  certainty  kulczynski
# 0        0.666667  0.666667   1.000000    0.833333
# 1        1.000000  0.666667   0.444444    0.833333
# 2        0.333333  0.500000   1.000000    0.750000
# 3        1.000000  0.750000   0.375000    0.875000
# 4        0.500000  0.750000   1.000000    0.875000
# 5        0.250000  0.500000   0.166667    0.666667
# 6        0.250000  0.500000   0.166667    0.666667
# 7       -0.333333  0.400000  -0.666667    0.583333
# 8        0.666667  0.666667   1.000000    0.833333
# 9        0.250000  0.500000   0.166667    0.666667
# 10       0.333333  0.500000   1.000000    0.750000
# 11       0.250000  0.500000   0.166667    0.666667
# 12       1.000000  0.666667   0.444444    0.833333

# %%
# Déterminer les règles d'association avec un lift > 1
rules2 = rules1[rules1['lift'] > 1].reset_index()


rules2
# Out:
#     index antecedents consequents  antecedent support  consequent support  \
# 0       0         (B)         (E)                 0.4                 0.6
# 1       1         (E)         (B)                 0.6                 0.4
# 2       2         (P)         (C)                 0.4                 0.8
# 3       3         (C)         (S)                 0.8                 0.6
# 4       4         (S)         (C)                 0.6                 0.8
# 5       5         (E)         (S)                 0.6                 0.6
# 6       6         (S)         (E)                 0.6                 0.6
# 7       8      (C, E)         (S)                 0.4                 0.6
# 8       9      (C, S)         (E)                 0.6                 0.6
# 9      10      (E, S)         (C)                 0.4                 0.8
# 10     11         (E)      (C, S)                 0.6                 0.6
# 11     12         (S)      (C, E)                 0.6                 0.4
#
#     support  confidence      lift  representativity  leverage  conviction  \
# 0       0.4    1.000000  1.666667               1.0      0.16         inf
# 1       0.4    0.666667  1.666667               1.0      0.16         1.8
# 2       0.4    1.000000  1.250000               1.0      0.08         inf
# 3       0.6    0.750000  1.250000               1.0      0.12         1.6
# 4       0.6    1.000000  1.250000               1.0      0.12         inf
# 5       0.4    0.666667  1.111111               1.0      0.04         1.2
# 6       0.4    0.666667  1.111111               1.0      0.04         1.2
# 7       0.4    1.000000  1.666667               1.0      0.16         inf
# 8       0.4    0.666667  1.111111               1.0      0.04         1.2
# 9       0.4    1.000000  1.250000               1.0      0.08         inf
# 10      0.4    0.666667  1.111111               1.0      0.04         1.2
# 11      0.4    0.666667  1.666667               1.0      0.16         1.8
#
#     zhangs_metric   jaccard  certainty  kulczynski
# 0        0.666667  0.666667   1.000000    0.833333
# 1        1.000000  0.666667   0.444444    0.833333
# 2        0.333333  0.500000   1.000000    0.750000
# 3        1.000000  0.750000   0.375000    0.875000
# 4        0.500000  0.750000   1.000000    0.875000
# 5        0.250000  0.500000   0.166667    0.666667
# 6        0.250000  0.500000   0.166667    0.666667
# 7        0.666667  0.666667   1.000000    0.833333
# 8        0.250000  0.500000   0.166667    0.666667
# 9        0.333333  0.500000   1.000000    0.750000
# 10       0.250000  0.500000   0.166667    0.666667
# 11       1.000000  0.666667   0.444444    0.833333

# %%
rules3 = rules2.sort_values(by='lift', ascending=False)[:4]
rules3
# Out:
#     index antecedents consequents  antecedent support  consequent support  \
# 0       0         (B)         (E)                 0.4                 0.6
# 1       1         (E)         (B)                 0.6                 0.4
# 7       8      (C, E)         (S)                 0.4                 0.6
# 11     12         (S)      (C, E)                 0.6                 0.4
#
#     support  confidence      lift  representativity  leverage  conviction  \
# 0       0.4    1.000000  1.666667               1.0      0.16         inf
# 1       0.4    0.666667  1.666667               1.0      0.16         1.8
# 7       0.4    1.000000  1.666667               1.0      0.16         inf
# 11      0.4    0.666667  1.666667               1.0      0.16         1.8
#
#     zhangs_metric   jaccard  certainty  kulczynski
# 0        0.666667  0.666667   1.000000    0.833333
# 1        1.000000  0.666667   0.444444    0.833333
# 7        0.666667  0.666667   1.000000    0.833333
# 11       1.000000  0.666667   0.444444    0.833333

# %%
rules3[(rules3[('antecedents')].ge({'E'})) & (rules3[('consequents')].ge({'S'}))]
# Out:
#    index antecedents consequents  antecedent support  consequent support  \
# 7      8      (C, E)         (S)                 0.4                 0.6
#
#    support  confidence      lift  representativity  leverage  conviction  \
# 7      0.4         1.0  1.666667               1.0      0.16         inf
#
#    zhangs_metric   jaccard  certainty  kulczynski
# 7       0.666667  0.666667        1.0    0.833333

# %%
c = np.linspace(1, 0.1, 10)
for i in c:
    try:
     rules = association_rules(apriori(dataset, min_support=i, use_colnames=True), metric="lift", min_threshold=1)
     if len(rules) >= 2:
        print("S_min={} ".format(i))
        break
    except: print("i{}, NO_FREQUENT_ITEMSET".format(i))
    else:
        print("i{}, NB_INTRESTING_RULES={}".format(i,len(rules)))
# Out:
# i1.0, NO_FREQUENT_ITEMSET
# i0.9, NO_FREQUENT_ITEMSET
# i0.8, NB_INTRESTING_RULES=0
# i0.7, NB_INTRESTING_RULES=0
# S_min=0.6
